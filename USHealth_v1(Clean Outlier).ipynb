# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#from tests.helpers import check
# pd.options.display.max_rows = 28
data = pd.read_csv(os.path.join('../data/HealthDataset3_Outlier.csv'))
# Pop out a quick sanity check
data
data.dtypes
# Out:
# CHSI_County_Name      object
# CHSI_State_Name       object
# Population_Size        int64
# Brst_Cancer          float64
# Col_Cancer           float64
#                       ...
# Sev_Work_Disabled      int64
# Major_Depression       int64
# Recent_Drug_Use        int64
# All_Death            float64
# Death_Rate           float64
# Length: 18, dtype: object

# %%
sns.set(rc={'figure.figsize':(100,15)})
sns.set(font_scale=4)
data['Death_Rate'].value_counts(bins=20).sort_index().plot.bar()

# %%
sns.set(rc={'figure.figsize':(3,8.27)})
sns.boxplot(data['Death_Rate'], data=data, orient='v')
data['Death_Rate'].describe()
# Out:
# count    300.000000
# mean       0.033063
# std        0.029852
# min        0.000100
# 25%        0.007575
# 50%        0.024350
# 75%        0.050425
# max        0.125100
# Name: Death_Rate, dtype: float64

# %%
##Injury boxplot
sns.set(rc={'figure.figsize':(3,8.27)})
p=sns.boxplot(y=data['Injury'], data=data)

# %%
sns.set(rc={'figure.figsize':(3,8.27)})
p=sns.boxplot(y=data['Brst_Cancer'], data=data)

# %%
sns.set(rc={'figure.figsize':(3,8.27)})
p=sns.boxplot(y=data['Col_Cancer'], data=data)

# %%
sns.set(rc={'figure.figsize':(3,8.27)})
p=sns.boxplot(y=data['CHD'], data=data)

# %%
sns.set(rc={'figure.figsize':(3,8.27)})
p=sns.boxplot(y=data['Lung_Cancer'], data=data)

# %%
sns.set(rc={'figure.figsize':(3,8.27)})
p=sns.boxplot(y=data['MVA'], data=data)

# %%
sns.set(rc={'figure.figsize':(3,8.27)})
p=sns.boxplot(y=data['Stroke'], data=data)

# %%
sns.set(rc={'figure.figsize':(3,8.27)})
p=sns.boxplot(y=data['Suicide'], data=data)

# %%
#4 different states All_Death
ax=sns.boxplot(x='CHSI_State_Name', y='All_Death', data=data, palette="Set2")
for patch in ax.artists:
 r, g, b, a = patch.get_facecolor()
 patch.set_facecolor((r, g, b, 1))

# %%
##All_Death VS No_HS_Diploma
from scipy import stats
g = sns.jointplot(x="All_Death", y="No_HS_Diploma", data=data, kind='reg', height=8)
g.annotate(stats.pearsonr)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
##All_Death VS Unemployed
from scipy import stats
g = sns.jointplot(x="All_Death", y="Unemployed", data=data, kind='reg', height=8)
g.annotate(stats.pearsonr)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
##All_Death VS Sev_Work_Disabled
from scipy import stats
g = sns.jointplot(x="All_Death", y="Sev_Work_Disabled", data=data, kind='reg', height=8)
g.annotate(stats.pearsonr)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
##All_Death VS Major_Depression
from scipy import stats
g = sns.jointplot(x="All_Death", y="Major_Depression", data=data, kind='reg', height=8)
g.annotate(stats.pearsonr)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
##All_Death VS Major_Depression
from scipy import stats
g = sns.jointplot(x="All_Death", y="Recent_Drug_Use", data=data, kind='reg', height=8)
g.annotate(stats.pearsonr)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
g = sns.jointplot(x="Unemployed", y="No_HS_Diploma", data=data, kind='reg', height=8)
g.annotate(stats.pearsonr)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
g = sns.jointplot(x="Unemployed", y="Recent_Drug_Use", data=data, kind='reg', height=8)
g.annotate(stats.pearsonr)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
g = sns.jointplot(x="No_HS_Diploma", y="Major_Depression", data=data, kind='reg', height=8)
g.annotate(stats.pearsonr)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
g = sns.jointplot(x="Major_Depression", y="Recent_Drug_Use", data=data, kind='reg', height=8)
g.annotate(stats.pearsonr)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
# y = data['Death_Rate'].iloc[:]
# x = data['CHSI_State_Name'].iloc[:]
#central tendency for a numeric variable with the height of each rectangle 

sns.set(rc={'figure.figsize':(30,15)})
sns.set(font_scale=2)
ax = sns.barplot(x='CHSI_State_Name', y='Death_Rate', data=data)

# %%
y = data['Death_Rate']
a = pd.Series(y, name="Death_Rate")
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.distplot(a)
y.describe()
# Out:
# count                 300.00
# mean                    0.03
# std                     0.03
# min                     0.00
# 25%                     0.01
# 50%                     0.02
# 75%                     0.05
# max                     0.13
# Name: Death_Rate, dtype: float64

# %%
data.iloc[:54].sort_values(by='Death_Rate', ascending=False).head(54)
# Out:
#    CHSI_County_Name CHSI_State_Name  Population_Size  Brst_Cancer  Col_Cancer  \
# 22            Modoc      California             9524         19.9        18.1
# 48          Trinity      California            13622         32.3        21.8
# 11             Inyo      California            18156         26.1        21.0
# 19         Mariposa      California            18069         32.3        19.2
# 4            Colusa      California            21095         21.1        23.8
# 28           Plumas      California            21477         32.8        18.7
# 8             Glenn      California            27759         28.4        21.2
# 15           Lassen      California            34751         16.8        11.8
# 1            Amador      California            38471         23.1        21.0
# 42         Siskiyou      California            45259         24.3        13.5
# 3         Calaveras      California            46871         18.8        15.2
# ...

# %%
sns.set(font_scale=1.5)
y=data.iloc[:54].sort_values(by='Death_Rate', ascending=False).head(54)['Death_Rate']
x=data.iloc[:54].sort_values(by='Death_Rate', ascending=False).head(54)['CHSI_County_Name']
sns.set_context({"figure.figsize": (30, 15)})
plt.xticks(rotation=45)
ax = sns.barplot(x,y, data=data, palette="Blues_d")

# %%
##ALl the county top 10 death rate
sns.set_context({"figure.figsize": (30, 15)})
b =data.sort_values(by='Death_Rate', ascending=False).head(10)['Death_Rate']
a =data.sort_values(by='Death_Rate', ascending=False).head(10)['CHSI_County_Name']
ax = sns.barplot(a, b, data=data, palette="Blues_d")

# %%
data.iloc[:54].sort_values(by='Death_Rate', ascending=False).head(10)
# Out:
#    CHSI_County_Name CHSI_State_Name  Population_Size  Brst_Cancer  Col_Cancer  \
# 22            Modoc      California             9524         19.9        18.1
# 48          Trinity      California            13622         32.3        21.8
# 11             Inyo      California            18156         26.1        21.0
# 19         Mariposa      California            18069         32.3        19.2
# 4            Colusa      California            21095         21.1        23.8
# 28           Plumas      California            21477         32.8        18.7
# 8             Glenn      California            27759         28.4        21.2
# 15           Lassen      California            34751         16.8        11.8
# 1            Amador      California            38471         23.1        21.0
# 42         Siskiyou      California            45259         24.3        13.5
#
#       CHD  Lung_Cancer   MVA  Stroke  Suicide  Injury  No_HS_Diploma  \
# ...

# %%
##California top 10 Death_Rate
sns.set_context({"figure.figsize": (30, 15)})
sns.set(font_scale=2)
b =data.iloc[:54].sort_values(by='Death_Rate', ascending=False).head(10)['Death_Rate']
a =data.iloc[:54].sort_values(by='Death_Rate', ascending=False).head(10)['CHSI_County_Name']
ax = sns.barplot(a, b, data=data, palette="Blues_d")

# %%
##Colorado top 10 Death_Rate
sns.set_context({"figure.figsize": (30, 15)})
sns.set(font_scale=2)
b =data.iloc[54:86].sort_values(by='Death_Rate', ascending=False).head(10)['Death_Rate']
a =data.iloc[54:86].sort_values(by='Death_Rate', ascending=False).head(10)['CHSI_County_Name']
ax = sns.barplot(a, b, data=data, palette="Blues_d")

# %%
data.iloc[54:86]
# Out:
#    CHSI_County_Name CHSI_State_Name  Population_Size  Brst_Cancer  Col_Cancer  \
# 54            Adams        Colorado           399426         25.3        21.4
# 55          Alamosa        Colorado            15282         15.9        22.6
# 56         Arapahoe        Colorado           529090         20.9        16.3
# 57          Boulder        Colorado           280440         21.8        16.1
# 58          Chaffee        Colorado            16968         21.3        14.7
# 59            Delta        Colorado            29947         25.9        18.1
# 60           Denver        Colorado           557917         23.9        20.2
# 61          Douglas        Colorado           249416         20.0        16.5
# 62           Elbert        Colorado            22788         41.2        18.2
# 63          El Paso        Colorado           565582         23.6        16.0
# 64          Fremont        Colorado            47766         24.6        18.2
# ...

# %%
data.iloc[86:172]
# Out:
#     CHSI_County_Name CHSI_State_Name  Population_Size  Brst_Cancer  \
# 86             Adams        Illinois            67040         22.4
# 87         Alexander        Illinois             8927         30.3
# 88              Bond        Illinois            18027         31.8
# 89             Boone        Illinois            50483         22.1
# 90            Bureau        Illinois            35330         27.5
# 91           Carroll        Illinois            16086         29.8
# 92              Cass        Illinois            13898         34.3
# 93         Champaign        Illinois           184905         29.0
# 94         Christian        Illinois            35176         22.8
# 95             Clark        Illinois            16976         22.1
# 96              Clay        Illinois            14122         29.7
# 97           Clinton        Illinois            36095         26.4
# 98             Coles        Illinois            51065         23.5
# ...

# %%
##Illinois top 10 Death_Rate
sns.set_context({"figure.figsize": (30, 15)})
sns.set(font_scale=2)
b =data.iloc[86:172].sort_values(by='Death_Rate', ascending=False).head(10)['Death_Rate']
a =data.iloc[86:172].sort_values(by='Death_Rate', ascending=False).head(10)['CHSI_County_Name']
ax = sns.barplot(a, b, data=data, palette="Blues_d")

# %%
sns.set_context({"figure.figsize": (30, 15)})
sns.set(font_scale=2)

b =data.iloc[172:300].sort_values(by='Death_Rate', ascending=False).head(10)['Death_Rate']
a =data.iloc[172:300].sort_values(by='Death_Rate', ascending=False).head(10)['CHSI_County_Name']
ax = sns.barplot(a, b, data=data, palette="Blues_d")

# %%
data.iloc[172:300]
# Out:
#     CHSI_County_Name CHSI_State_Name  Population_Size  Brst_Cancer  \
# 172          Appling         Georgia            17954         20.7
# 173            Bacon         Georgia            10379         28.3
# 174          Baldwin         Georgia            45230         22.6
# 175            Banks         Georgia            16055         21.7
# 176           Barrow         Georgia            59954         21.1
# 177           Bartow         Georgia            89229         24.8
# 178         Ben Hill         Georgia            17316         27.6
# 179          Berrien         Georgia            16708         24.9
# 180             Bibb         Georgia           154918         26.4
# 181         Bleckley         Georgia            12141         13.8
# 182         Brantley         Georgia            15491         17.2
# 183           Brooks         Georgia            16327         16.3
# 184            Bryan         Georgia            28549         25.5
# ...

# %%
x=data['CHSI_State_Name']
a=data['Brst_Cancer']
b=data['Col_Cancer']
c=data['CHD']
d=data['Lung_Cancer']
e=data['MVA']
f=data['Stroke']
g=data['Suicide']
h=data['Injury']

sns.set(font_scale=2)
sns.set_context({"figure.figsize": (30, 20)})
p1=plt.bar(x, a, width=1, edgecolor='#be4e54',color='#be4e54', )
p2=plt.bar(x, b, width=1, bottom=a, edgecolor='#6eb4cd',color='#6eb4cd')
p3=plt.bar(x, c, width=1, bottom=b, edgecolor='#caba74',color='#caba74')
p4=plt.bar(x, d, width=1, bottom=c, edgecolor='#92d2bf',color='#92d2bf')
p5=plt.bar(x, e, width=1, bottom=d, edgecolor='pink',color='pink')
p6=plt.bar(x, f, width=1, bottom=e, edgecolor='#5fa967',color='#5fa967')
p7=plt.bar(x, g, width=1, bottom=f, edgecolor='#2c76b4',color='#2c76b4')
p8=plt.bar(x, h, width=1, bottom=g, edgecolor='#1d5ba0',color='#1d5ba0')
plt.legend((p1[0], p2[0],p3[0],p4[0],p5[0],p6[0],p7[0],p8[0]), ('Brst_Cancer', 'Col_Cancer','CHD','Lung_Cancer','MVA','Stroke','Suicide','Injury'))

# %%
x=data['CHSI_State_Name']
a=data['All_Death']
b=data['No_HS_Diploma']
c=data['Unemployed']
d=data['Sev_Work_Disabled']
e=data['Major_Depression']
f=data['Recent_Drug_Use']

sns.set(font_scale=2)
sns.set_context({"figure.figsize": (30, 20)})
p1=plt.bar(x, a, width=1, edgecolor='#be4e54',color='#be4e54', )
p2=plt.bar(x, b, width=1, bottom=a, edgecolor='#6eb4cd',color='#6eb4cd')
p3=plt.bar(x, c, width=1, bottom=b, edgecolor='#caba74',color='#caba74')
p4=plt.bar(x, d, width=1, bottom=c, edgecolor='#92d2bf',color='#92d2bf')
p5=plt.bar(x, e, width=1, bottom=d, edgecolor='pink',color='pink')
p6=plt.bar(x, f, width=1, bottom=e, edgecolor='#5fa967',color='#5fa967')

plt.legend((p1[0], p2[0],p3[0],p4[0],p5[0],p6[0]), ('All_Death','No_HS_Diploma', 'Unemployed','Sev_Work_Disabled','Major_Depression','Recent_Drug_Use'))

# %%
from sklearn.utils import shuffle
from sklearn.linear_model import LinearRegression
pd.set_option('precision',2)
pd.set_option('display.max_rows',10)
pd.set_option('display.float_format', '{:20,.2f}'.format)
plt.style.use('seaborn')

data.head()
data = shuffle(data)
data_train = data.head(210)
data_test = data.tail(90)

# %%
from sklearn import linear_model
import statsmodels.api as sm

ols_sl = linear_model.LinearRegression(fit_intercept=True)

x_train=data_train[['No_HS_Diploma','Unemployed','Sev_Work_Disabled','Major_Depression','Recent_Drug_Use']]
y_train=data_train['Death_Rate']
ols_sm = sm.OLS(y_train, sm.add_constant(x_train))

ols_sm_result = ols_sm.fit()

#summary
ols_sm_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Death_Rate   R-squared:                       0.520
# Model:                            OLS   Adj. R-squared:                  0.508
# Method:                 Least Squares   F-statistic:                     44.19
# Date:                Sat, 02 Mar 2019   Prob (F-statistic):           9.26e-31
# Time:                        11:55:15   Log-Likelihood:                 527.76
# No. Observations:                 210   AIC:                            -1044.
# Df Residuals:                     204   BIC:                            -1023.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
## y_true and y_pred
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

red_patch =mpatches.Patch(color='red', label='y_true')
blue_patch=mpatches.Patch(color='blue', label='y_pred')
plt.legend(handles=[red_patch,blue_patch])

y_true.reset_index(drop=True, inplace = True)
sns.set(font_scale=5)
sns.set_context({"figure.figsize": (30, 15)})
plt.plot(y_true, color="red",linewidth=2)
plt.plot(y_pred,color="blue",linewidth=2)
#plt.legend([p1,p2], ['y_true','y_pred'], loc='lower left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-461bd7564a6b> in <module>
#       7 plt.legend(handles=[red_patch,blue_patch])
#       8
# ----> 9 y_true.reset_index(drop=True, inplace = True)
#      10 sns.set(font_scale=5)
#      11 sns.set_context({"figure.figsize": (30, 15)})
#
# NameError: name 'y_true' is not defined
